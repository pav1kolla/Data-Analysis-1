# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# A-1 Perform general Data analysis?

# %%
data1 = pd.read_csv(r"C:\Users\pavan\Downloads\autos.csv",encoding="utf-8")

# %%
data1
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
data=data1.copy()

# %%
data
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          371528 non-null  object
#  1   name                 371528 non-null  object
#  2   seller               371528 non-null  object
#  3   offerType            371528 non-null  object
#  4   price                371528 non-null  int64
#  5   abtest               371528 non-null  object
#  6   vehicleType          333659 non-null  object
#  7   yearOfRegistration   371528 non-null  int64
#  8   gearbox              351319 non-null  object
#  9   powerPS              371528 non-null  int64
#  10  model                351044 non-null  object
#  11  kilometer            371528 non-null  int64
#  12  monthOfRegistration  371528 non-null  int64
#  13  fuelType             338142 non-null  object
#  14  brand                371528 non-null  object
# ...

# %%
data.describe()
# Out:
#               price  yearOfRegistration        powerPS      kilometer  \
# count  3.715280e+05       371528.000000  371528.000000  371528.000000
# mean   1.729514e+04         2004.577997     115.549477  125618.688228
# std    3.587954e+06           92.866598     192.139578   40112.337051
# min    0.000000e+00         1000.000000       0.000000    5000.000000
# 25%    1.150000e+03         1999.000000      70.000000  125000.000000
# 50%    2.950000e+03         2003.000000     105.000000  150000.000000
# 75%    7.200000e+03         2008.000000     150.000000  150000.000000
# max    2.147484e+09         9999.000000   20000.000000  150000.000000
#
#        monthOfRegistration  nrOfPictures    postalCode
# count        371528.000000      371528.0  371528.00000
# mean              5.734445           0.0   50820.66764
# std               3.712412           0.0   25799.08247
# min               0.000000           0.0    1067.00000
# 25%               3.000000           0.0   30459.00000
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %% [markdown]
# # A-2 Can you tell me the Distribution of Vehicles based on Year of Registration with the help of a plot ?

# %%
data['yearOfRegistration']=data['yearOfRegistration'].where((data['yearOfRegistration']>1950)&(data['yearOfRegistration']<2023),data['yearOfRegistration'].mode()[0])

# %%
sns.kdeplot(x=data['yearOfRegistration'])
plt.show()

# %% [markdown]
# # A-3 Create a plot based on the Variation of the price range by the vehicle type ?

# %%
sns.barplot(data=data,x='price',y='vehicleType',errorbar=('ci',False))
plt.title('Variation of the price range by the vehicle type',color='g')
plt.show()

# %% [markdown]
# # A-4. Find out Total count of vehicles by type available on ebay for sale.As well as create a visualization for the client ?

# %%
data['vehicleType'].value_counts()
# Out:
# limousine     95894
# kleinwagen    80022
# kombi         67563
# bus           30201
# cabrio        22898
# coupe         19013
# suv           14707
# andere         3357
# Name: vehicleType, dtype: int64

# %%
sns.countplot(y=data['vehicleType'])
plt.title('vehicle types and their respective counts')
plt.show()

# %% [markdown]
# # A-5. Is there any relationship between dollar_price and kilometer? (Explain with appropriate analysis) ?

# %%
corr=data[["price","kilometer"]].corr(method="spearman")

# %%
corr
# Out:
#              price  kilometer
# price      1.00000   -0.37305
# kilometer -0.37305    1.00000

# %%
sns.regplot(x='kilometer',y='price',data=corr)
plt.show()

# %% [markdown]
# # B-1 Can you tell me No of Vehicles by Brand Available on ebay for sale with the help of visualization ?

# %%
sns.countplot(y=data['brand'])
plt.title('brands and their respective sales counts')
plt.show()

# %% [markdown]
# # B- 2. What is the Average price for vehicles based on the type of vehicle as well as on the type of gearbox.Explain me with both numerical and visualization analysis ?

# %%
group=data.groupby(['vehicleType','gearbox'])['price'].agg('mean').reset_index()

# %%
group.head(15)
# Out:
#    vehicleType    gearbox          price
# 0       andere  automatik    7366.861496
# 1       andere    manuell  825539.352000
# 2       andere     noname    3661.203252
# 3          bus  automatik   10599.265713
# 4          bus    manuell    6321.168265
# 5          bus     noname  124897.289820
# 6       cabrio  automatik   16254.374208
# 7       cabrio    manuell   14897.823880
# 8       cabrio     noname    9751.342246
# 9        coupe  automatik   35510.948175
# 10       coupe    manuell   12400.255031
# 11       coupe     noname  233553.441558
# 12  kleinwagen  automatik    3889.552200
# 13  kleinwagen    manuell    4606.803784
# 14  kleinwagen     noname   33104.509510

# %%
data['gearbox'].fillna('noname',inplace=True)

# %%
data['vehicleType'].fillna('noname',inplace=True)

# %%
data['vehicleType'].unique()
# Out:
# array(['noname', 'coupe', 'suv', 'kleinwagen', 'limousine', 'cabrio',
#        'bus', 'kombi', 'andere'], dtype=object)

# %%
data['gearbox'].unique()
# Out:
# array(['manuell', 'automatik', 'noname'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 371524 entries, 0 to 371527
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   name                 371524 non-null  object
#  1   seller               371524 non-null  object
#  2   offerType            371524 non-null  object
#  3   price                371524 non-null  int64
#  4   abtest               371524 non-null  object
#  5   vehicleType          371524 non-null  object
#  6   yearOfRegistration   371524 non-null  int64
#  7   gearbox              371524 non-null  object
#  8   powerPS              371524 non-null  int64
#  9   model                351040 non-null  object
#  10  kilometer            371524 non-null  int64
#  11  monthOfRegistration  371524 non-null  int64
#  12  fuelType             338138 non-null  object
#  13  brand                371524 non-null  object
#  14  notRepairedDamage    299464 non-null  object
# ...

# %%
data['vehicleType']
# Out:
# 0             noname
# 1              coupe
# 2                suv
# 3         kleinwagen
# 4         kleinwagen
#              ...
# 371523        noname
# 371524        cabrio
# 371525           bus
# 371526         kombi
# 371527     limousine
# Name: vehicleType, Length: 371524, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 371524 entries, 0 to 371527
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   name                 371524 non-null  object
#  1   seller               371524 non-null  object
#  2   offerType            371524 non-null  object
#  3   price                371524 non-null  int64
#  4   abtest               371524 non-null  object
#  5   vehicleType          371524 non-null  object
#  6   yearOfRegistration   371524 non-null  int64
#  7   gearbox              371524 non-null  object
#  8   powerPS              371524 non-null  int64
#  9   model                351040 non-null  object
#  10  kilometer            371524 non-null  int64
#  11  monthOfRegistration  371524 non-null  int64
#  12  fuelType             338138 non-null  object
#  13  brand                371524 non-null  object
#  14  notRepairedDamage    299464 non-null  object
# ...

# %%
sns.barplot(x='vehicleType',y='price',hue='gearbox',data=group)
plt.xlabel('vehicleType',color='b')
plt.ylabel('avgprice',color='r')
plt.title('avgs for gearbox and vehicleType',color='r')
plt.show()

# %% [markdown]
# # B-3 What is the marginal probability of private seller ?

# %%
pd.crosstab(index=data["seller"]=="privat",columns=data["seller"]=="gewerblich",rownames=["privat"],colnames=["gewerblich"],normalize='columns',margins=True)
# Out:
# gewerblich  False  True       All
# privat
# False         0.0   1.0  0.000008
# True          1.0   0.0  0.999992

# %% [markdown]
# # C-1 The memory usage of the data is around 6.1 mb.How can we reduce the memory usage of the data set?

# %%
data.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
data.drop(["nrOfPictures"],axis=1,inplace=True)

# %%
data.drop(["dateCrawled"],axis=1,inplace=True)

# %%
data.drop(["dateCreated"],axis=1,inplace=True)

# %%
data.drop(["postalCode"],axis=1,inplace=True)

# %%
data.drop(["lastSeen"],axis=1,inplace=True)

# %%
data["price"]=data["price"].astype(np.int32)

# %%
data["kilometer"]=data["kilometer"].astype(np.int32)

# %%
data["monthOfRegistration"]=data["monthOfRegistration"].astype(np.int8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 371524 entries, 0 to 371527
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   name                 371524 non-null  object
#  1   seller               371524 non-null  object
#  2   offerType            371524 non-null  object
#  3   price                371524 non-null  int32
#  4   abtest               371524 non-null  object
#  5   vehicleType          333655 non-null  object
#  6   yearOfRegistration   371524 non-null  int64
#  7   gearbox              351315 non-null  object
#  8   powerPS              371524 non-null  int64
#  9   model                351040 non-null  object
#  10  kilometer            371524 non-null  int32
#  11  monthOfRegistration  371524 non-null  int8
#  12  fuelType             338138 non-null  object
#  13  brand                371524 non-null  object
#  14  notRepairedDamage    299464 non-null  object
# ...

# %%
data.columns
# Out:
# Index(['name', 'seller', 'offerType', 'price', 'abtest', 'vehicleType',
#        'yearOfRegistration', 'gearbox', 'powerPS', 'model', 'kilometer',
#        'monthOfRegistration', 'fuelType', 'brand', 'notRepairedDamage'],
#       dtype='object')

# %% [markdown]
# # C-2. What is the Average price of vehicle by fuel type and gearbox type.Give a plot ?¶

# %%
group1=data.groupby(['fuelType','gearbox'])

# %%
cat=group1['price'].mean()

# %%
data['fuelType'].fillna('noname',inplace=True)

# %%
cat
# Out:
# fuelType  gearbox
# andere    automatik    8.434172e+03
#           manuell      1.732090e+07
#           noname       2.170582e+03
# benzin    automatik    1.224912e+04
#           manuell      6.567152e+03
#           noname       4.902964e+04
# cng       automatik    6.737718e+03
#           manuell      4.572039e+03
#           noname       2.499429e+03
# diesel    automatik    1.881035e+04
#           manuell      7.326334e+03
#           noname       3.193673e+04
# elektro   automatik    2.290028e+04
#           manuell      3.384615e+03
#           noname       4.296500e+03
# hybrid    automatik    1.528196e+04
#           manuell      1.201370e+04
#           noname       9.309875e+03
# lpg       automatik    2.219599e+04
#           manuell      3.255393e+03
#           noname       2.791691e+03
# Name: price, dtype: float64

# %%
group3=data.groupby(['gearbox','fuelType'])['price'].agg('mean').reset_index()

# %%
group3
# Out:
#       gearbox fuelType         price
# 0   automatik   andere  8.434172e+03
# 1   automatik   benzin  1.224912e+04
# 2   automatik      cng  6.737718e+03
# 3   automatik   diesel  1.881035e+04
# 4   automatik  elektro  2.290028e+04
# 5   automatik   hybrid  1.528196e+04
# 6   automatik      lpg  2.219599e+04
# 7   automatik   noname  8.150886e+03
# 8     manuell   andere  1.732090e+07
# 9     manuell   benzin  6.567152e+03
# 10    manuell      cng  4.572039e+03
# 11    manuell   diesel  7.326334e+03
# 12    manuell  elektro  3.384615e+03
# 13    manuell   hybrid  1.201370e+04
# 14    manuell      lpg  3.255393e+03
# 15    manuell   noname  2.523221e+04
# 16     noname   andere  2.170582e+03
# 17     noname   benzin  4.902964e+04
# 18     noname      cng  2.499429e+03
# 19     noname   diesel  3.193673e+04
# 20     noname  elektro  4.296500e+03
# 21     noname   hybrid  9.309875e+03
# 22     noname      lpg  2.791691e+03
# 23     noname   noname  4.592026e+04

# %%
sns.pointplot(group3,x='fuelType',y='price',hue="gearbox")
plt.xlabel('gearbox',color='r')
plt.ylabel('fuelType',color='b')
plt.title('avgs for gearbox and fueltype',color='g')
plt.show()

# %% [markdown]
# # C-3  What is the Average power of a vehicle by vehicle type and gearbox type.Give a plot?

# %%
group4=data.groupby(['gearbox','vehicleType'])['price'].agg('mean').reset_index()

# %%
sns.barplot(group4,x="vehicleType",y="price",hue="gearbox")
plt.xlabel('gearbox',color='r')
plt.ylabel('vehicleType',color='b')
plt.title('average prices of vehicleType with gearbox',color='g')
plt.show()

# %% [markdown]
# # C-4. What is the Average price of a vehicle by brand as well as vehicle type.Use heatmap to explain this ?

# %%
group=data.groupby(['brand','vehicleType'])['price'].agg('mean').unstack()

# %%
group
# Out:
# vehicleType           andere           bus        cabrio          coupe  \
# brand
# alfa_romeo      3.153333e+03           NaN   9147.179487    6897.190083
# audi            9.768120e+04   3485.000000  13441.196564   16341.915486
# bmw             2.686439e+03  27569.884615  38010.594552   32097.647113
# chevrolet       1.003280e+04   6189.300000  24026.621622   16317.023438
# chrysler        8.888333e+03   2630.515982   4324.531120    9174.240000
# citroen         3.521024e+03   4409.132179   4536.408696    2695.552632
# dacia           4.450000e+03   8606.700000           NaN            NaN
# daewoo          9.938000e+02   1262.777778    900.000000     428.625000
# daihatsu        1.075000e+03   1201.500000   7761.000000            NaN
# fiat            3.534768e+03   4014.823460   6485.634286    3801.477778
# ford            4.089282e+03   6028.413458   5471.103125    8217.211306
# honda           2.417000e+03   4551.638554   5336.653846    3065.749380
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(group,annot=True,fmt='.2f',cbar=True)
plt.xlabel('brand')
plt.ylabel('vehicleType')
plt.title('avgs')
plt.show()
